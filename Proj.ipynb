# %% [markdown]
# # IPL Win % Calculator Project

# %% [markdown]
# <b>The Aim: </b>We will use Logistic Regression to build`a model where we will predict the win percentage of the teams in any given ball in the second innings of the game.<br>
# <b>Datasets: </b>We download the <i>matches.csv</i> containing information about every IPL match from 2008-2024 and <i>deliveries.csv</i> containing information about every ball bowled in those matches from <a href="https://www.kaggle.com/datasets/patrickb1912/ipl-complete-dataset-20082020/data"><u>Kaggle</u></a>

# %% [markdown]
# ### 1. Importing libraries and datasets

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
matches = pd.read_csv('./data/matches.csv')
deliveries = pd.read_csv('./data/deliveries.csv')

# %% [markdown]
# ### 2. Exploring the data

# %%
matches.head()
# Out:
#        id   season        city        date match_type player_of_match  \
# 0  335982  2007/08   Bangalore  2008-04-18     League     BB McCullum
# 1  335983  2007/08  Chandigarh  2008-04-19     League      MEK Hussey
# 2  335984  2007/08       Delhi  2008-04-19     League     MF Maharoof
# 3  335985  2007/08      Mumbai  2008-04-20     League      MV Boucher
# 4  335986  2007/08     Kolkata  2008-04-20     League       DJ Hussey
#
#                                         venue                        team1  \
# 0                       M Chinnaswamy Stadium  Royal Challengers Bangalore
# 1  Punjab Cricket Association Stadium, Mohali              Kings XI Punjab
# 2                            Feroz Shah Kotla             Delhi Daredevils
# 3                            Wankhede Stadium               Mumbai Indians
# 4                                Eden Gardens        Kolkata Knight Riders
#
#                          team2                  toss_winner toss_decision  \
# 0        Kolkata Knight Riders  Royal Challengers Bangalore         field
# 1          Chennai Super Kings          Chennai Super Kings           bat
# 2             Rajasthan Royals             Rajasthan Royals           bat
# 3  Royal Challengers Bangalore               Mumbai Indians           bat
# 4              Deccan Chargers              Deccan Chargers           bat
#
#                         winner   result  result_margin  target_runs  \
# 0        Kolkata Knight Riders     runs          140.0        223.0
# 1          Chennai Super Kings     runs           33.0        241.0
# 2             Delhi Daredevils  wickets            9.0        130.0
# 3  Royal Challengers Bangalore  wickets            5.0        166.0
# 4        Kolkata Knight Riders  wickets            5.0        111.0
#
#    target_overs super_over method    umpire1         umpire2
# 0          20.0          N    NaN  Asad Rauf     RE Koertzen
# 1          20.0          N    NaN  MR Benson      SL Shastri
# 2          20.0          N    NaN  Aleem Dar  GA Pratapkumar
# 3          20.0          N    NaN   SJ Davis       DJ Harper
# 4          20.0          N    NaN  BF Bowden     K Hariharan

# %%
deliveries.head()
# Out:
#    match_id  inning           batting_team                 bowling_team  over  \
# 0    335982       1  Kolkata Knight Riders  Royal Challengers Bangalore     0
# 1    335982       1  Kolkata Knight Riders  Royal Challengers Bangalore     0
# 2    335982       1  Kolkata Knight Riders  Royal Challengers Bangalore     0
# 3    335982       1  Kolkata Knight Riders  Royal Challengers Bangalore     0
# 4    335982       1  Kolkata Knight Riders  Royal Challengers Bangalore     0
#
#    ball       batter   bowler  non_striker  batsman_runs  extra_runs  \
# 0     1   SC Ganguly  P Kumar  BB McCullum             0           1
# 1     2  BB McCullum  P Kumar   SC Ganguly             0           0
# 2     3  BB McCullum  P Kumar   SC Ganguly             0           1
# 3     4  BB McCullum  P Kumar   SC Ganguly             0           0
# 4     5  BB McCullum  P Kumar   SC Ganguly             0           0
#
#    total_runs extras_type  is_wicket player_dismissed dismissal_kind fielder
# 0           1     legbyes          0              NaN            NaN     NaN
# 1           0         NaN          0              NaN            NaN     NaN
# 2           1       wides          0              NaN            NaN     NaN
# 3           0         NaN          0              NaN            NaN     NaN
# 4           0         NaN          0              NaN            NaN     NaN

# %%
deliveries.shape
# Out:
# (260920, 17)

# %%
matches.shape
# Out:
# (1095, 20)

# %% [markdown]
# Here we know that many teams in IPL have changed names along the years. We need to treat them as the same team to keep their records together

# %%
matches["team1"].unique()
# Out:
# array(['Royal Challengers Bangalore', 'Kings XI Punjab',
#        'Delhi Daredevils', 'Mumbai Indians', 'Kolkata Knight Riders',
#        'Rajasthan Royals', 'Deccan Chargers', 'Chennai Super Kings',
#        'Kochi Tuskers Kerala', 'Pune Warriors', 'Sunrisers Hyderabad',
#        'Gujarat Lions', 'Rising Pune Supergiants',
#        'Rising Pune Supergiant', 'Delhi Capitals', 'Punjab Kings',
#        'Lucknow Super Giants', 'Gujarat Titans',
#        'Royal Challengers Bengaluru'], dtype=object)

# %%
matches['team1'] = matches['team1'].str.replace('Delhi Daredevils', 'Delhi Capitals')
matches['team2'] = matches['team2'].str.replace('Delhi Daredevils', 'Delhi Capitals')

matches['team1'] = matches['team1'].str.replace('Deccan Chargers', 'Sunrisers Hyderabad')
matches['team2'] = matches['team2'].str.replace('Deccan Chargers', 'Sunrisers Hyderabad')

matches['team1'] = matches['team1'].str.replace('Kings XI Punjab', 'Punjab Kings')
matches['team2'] = matches['team2'].str.replace('Kings XI Punjab', 'Punjab Kings')

matches['team1'] = matches['team1'].str.replace('Royal Challengers Bengaluru', 'Royal Challengers Bangalore')
matches['team2'] = matches['team2'].str.replace('Royal Challengers Bengaluru', 'Royal Challengers Bangalore')

# %% [markdown]
# Also many of the teams in history don't play anymore so we don't have to train the model on them since we wouldn't use it on them anyway

# %%
teams = ['Royal Challengers Bangalore', 'Mumbai Indians', 'Kolkata Knight Riders',
       'Rajasthan Royals', 'Chennai Super Kings', 'Sunrisers Hyderabad',
        'Delhi Capitals', 'Punjab Kings']

# %%
matches = matches[matches['team1'].isin(teams)]
matches = matches[matches['team2'].isin(teams)]
matches.shape
# Out:
# (896, 20)

# %% [markdown]
# Now we will remove the matches where D/L method was used since the normal deliveries of the match would be irrelevant to the final result in those matches

# %%
matches["method"].unique()
# Out:
# array([nan, 'D/L'], dtype=object)

# %%
matches = matches[matches["method"] != 'D/L']
matches.shape
# Out:
# (880, 20)

# %% [markdown]
# Here we're going to extract the final features we need from the matches dataset, i.e, the <b>match id</b>, <b>city</b> where match is held, <b>target runs</b>, and the <b>winner</b>

# %%
match_df = matches[['id', 'winner', 'target_runs', 'city']]

# %% [markdown]
# We're going to join the match_df and deliveries dataframe by joining on the 'match_id' column to make delivery_df.<br>
# For that we need to rename 'id' to 'match_id' so it matches in both

# %%
match_df = match_df.rename(columns={'id': 'match_id'})

# %%
delivery_df = match_df.merge(deliveries, on='match_id')

# %%
delivery_df.head()
# Out:
#    match_id                 winner  target_runs       city  inning  \
# 0    335982  Kolkata Knight Riders        223.0  Bangalore       1
# 1    335982  Kolkata Knight Riders        223.0  Bangalore       1
# 2    335982  Kolkata Knight Riders        223.0  Bangalore       1
# 3    335982  Kolkata Knight Riders        223.0  Bangalore       1
# 4    335982  Kolkata Knight Riders        223.0  Bangalore       1
#
#             batting_team                 bowling_team  over  ball  \
# 0  Kolkata Knight Riders  Royal Challengers Bangalore     0     1
# 1  Kolkata Knight Riders  Royal Challengers Bangalore     0     2
# 2  Kolkata Knight Riders  Royal Challengers Bangalore     0     3
# 3  Kolkata Knight Riders  Royal Challengers Bangalore     0     4
# 4  Kolkata Knight Riders  Royal Challengers Bangalore     0     5
#
#         batter   bowler  non_striker  batsman_runs  extra_runs  total_runs  \
# 0   SC Ganguly  P Kumar  BB McCullum             0           1           1
# 1  BB McCullum  P Kumar   SC Ganguly             0           0           0
# 2  BB McCullum  P Kumar   SC Ganguly             0           1           1
# 3  BB McCullum  P Kumar   SC Ganguly             0           0           0
# 4  BB McCullum  P Kumar   SC Ganguly             0           0           0
#
#   extras_type  is_wicket player_dismissed dismissal_kind fielder
# 0     legbyes          0              NaN            NaN     NaN
# 1         NaN          0              NaN            NaN     NaN
# 2       wides          0              NaN            NaN     NaN
# 3         NaN          0              NaN            NaN     NaN
# 4         NaN          0              NaN            NaN     NaN

# %% [markdown]
# UPDATE: We will have to replace the names of the teams which have changed names again in the delivery_df

# %%
delivery_df['batting_team'] = delivery_df['batting_team'].str.replace('Delhi Daredevils', 'Delhi Capitals')
delivery_df['bowling_team'] = delivery_df['bowling_team'].str.replace('Delhi Daredevils', 'Delhi Capitals')

delivery_df['batting_team'] = delivery_df['batting_team'].str.replace('Deccan Chargers', 'Sunrisers Hyderabad')
delivery_df['bowling_team'] = delivery_df['bowling_team'].str.replace('Deccan Chargers', 'Sunrisers Hyderabad')

delivery_df['batting_team'] = delivery_df['batting_team'].str.replace('Kings XI Punjab', 'Punjab Kings')
delivery_df['bowling_team'] = delivery_df['bowling_team'].str.replace('Kings XI Punjab', 'Punjab Kings')

delivery_df['batting_team'] = delivery_df['batting_team'].str.replace('Royal Challengers Bengaluru', 'Royal Challengers Bangalore')
delivery_df['bowling_team'] = delivery_df['bowling_team'].str.replace('Royal Challengers Bengaluru', 'Royal Challengers Bangalore')

# %% [markdown]
# Since we're only going to predict using balls in the second innings, we can eliminate all the balls of the first innings from the data

# %%
delivery_df = delivery_df[delivery_df["inning"] == 2]
delivery_df.tail()
# Out:
#         match_id                 winner  target_runs     city  inning  \
# 210963   1426312  Kolkata Knight Riders        114.0  Chennai       2
# 210964   1426312  Kolkata Knight Riders        114.0  Chennai       2
# 210965   1426312  Kolkata Knight Riders        114.0  Chennai       2
# 210966   1426312  Kolkata Knight Riders        114.0  Chennai       2
# 210967   1426312  Kolkata Knight Riders        114.0  Chennai       2
#
#                  batting_team         bowling_team  over  ball   batter  \
# 210963  Kolkata Knight Riders  Sunrisers Hyderabad     9     5  SS Iyer
# 210964  Kolkata Knight Riders  Sunrisers Hyderabad     9     6  VR Iyer
# 210965  Kolkata Knight Riders  Sunrisers Hyderabad    10     1  VR Iyer
# 210966  Kolkata Knight Riders  Sunrisers Hyderabad    10     2  SS Iyer
# 210967  Kolkata Knight Riders  Sunrisers Hyderabad    10     3  VR Iyer
#
#                bowler non_striker  batsman_runs  extra_runs  total_runs  \
# 210963     AK Markram     VR Iyer             1           0           1
# 210964     AK Markram     SS Iyer             1           0           1
# 210965  Shahbaz Ahmed     SS Iyer             1           0           1
# 210966  Shahbaz Ahmed     VR Iyer             1           0           1
# 210967  Shahbaz Ahmed     SS Iyer             1           0           1
#
#        extras_type  is_wicket player_dismissed dismissal_kind fielder
# 210963         NaN          0              NaN            NaN     NaN
# 210964         NaN          0              NaN            NaN     NaN
# 210965         NaN          0              NaN            NaN     NaN
# 210966         NaN          0              NaN            NaN     NaN
# 210967         NaN          0              NaN            NaN     NaN

# %%
delivery_df.shape
# Out:
# (102034, 20)

# %% [markdown]
# Here we use <i>cumsum</i> to calculate <b>runs scored</b> at every ball

# %%
delivery_df['current_score'] = delivery_df.groupby('match_id')['total_runs'].transform('cumsum')

# %%
delivery_df.head()
# Out:
#      match_id                 winner  target_runs       city  inning  \
# 124    335982  Kolkata Knight Riders        223.0  Bangalore       2
# 125    335982  Kolkata Knight Riders        223.0  Bangalore       2
# 126    335982  Kolkata Knight Riders        223.0  Bangalore       2
# 127    335982  Kolkata Knight Riders        223.0  Bangalore       2
# 128    335982  Kolkata Knight Riders        223.0  Bangalore       2
#
#                     batting_team           bowling_team  over  ball    batter  \
# 124  Royal Challengers Bangalore  Kolkata Knight Riders     0     1  R Dravid
# 125  Royal Challengers Bangalore  Kolkata Knight Riders     0     2  W Jaffer
# 126  Royal Challengers Bangalore  Kolkata Knight Riders     0     3  W Jaffer
# 127  Royal Challengers Bangalore  Kolkata Knight Riders     0     4  W Jaffer
# 128  Royal Challengers Bangalore  Kolkata Knight Riders     0     5  R Dravid
#
#      ... non_striker batsman_runs  extra_runs  total_runs  extras_type  \
# 124  ...    W Jaffer            1           0           1          NaN
# 125  ...    R Dravid            0           1           1        wides
# 126  ...    R Dravid            0           0           0          NaN
# 127  ...    R Dravid            1           0           1          NaN
# 128  ...    W Jaffer            1           0           1          NaN
#
#     is_wicket  player_dismissed dismissal_kind fielder current_score
# 124         0               NaN            NaN     NaN             1
# 125         0               NaN            NaN     NaN             2
# 126         0               NaN            NaN     NaN             2
# 127         0               NaN            NaN     NaN             3
# 128         0               NaN            NaN     NaN             4
#
# [5 rows x 21 columns]

# %% [markdown]
# And then calculate <b>runs_left</b> by subtracting runs_scored from target_runs

# %%
delivery_df['runs_left'] = delivery_df['target_runs'] - delivery_df['current_score']
delivery_df.head()
# Out:
#      match_id                 winner  target_runs       city  inning  \
# 124    335982  Kolkata Knight Riders        223.0  Bangalore       2
# 125    335982  Kolkata Knight Riders        223.0  Bangalore       2
# 126    335982  Kolkata Knight Riders        223.0  Bangalore       2
# 127    335982  Kolkata Knight Riders        223.0  Bangalore       2
# 128    335982  Kolkata Knight Riders        223.0  Bangalore       2
#
#                     batting_team           bowling_team  over  ball    batter  \
# 124  Royal Challengers Bangalore  Kolkata Knight Riders     0     1  R Dravid
# 125  Royal Challengers Bangalore  Kolkata Knight Riders     0     2  W Jaffer
# 126  Royal Challengers Bangalore  Kolkata Knight Riders     0     3  W Jaffer
# 127  Royal Challengers Bangalore  Kolkata Knight Riders     0     4  W Jaffer
# 128  Royal Challengers Bangalore  Kolkata Knight Riders     0     5  R Dravid
#
#      ... batsman_runs extra_runs  total_runs  extras_type  is_wicket  \
# 124  ...            1          0           1          NaN          0
# 125  ...            0          1           1        wides          0
# 126  ...            0          0           0          NaN          0
# 127  ...            1          0           1          NaN          0
# 128  ...            1          0           1          NaN          0
#
#     player_dismissed  dismissal_kind fielder current_score runs_left
# 124              NaN             NaN     NaN             1     222.0
# 125              NaN             NaN     NaN             2     221.0
# 126              NaN             NaN     NaN             2     221.0
# 127              NaN             NaN     NaN             3     220.0
# 128              NaN             NaN     NaN             4     219.0
#
# [5 rows x 22 columns]

# %%
delivery_df['balls_left'] = 120 - (delivery_df['over']*6 + delivery_df['ball'])
delivery_df.head()
# Out:
#      match_id                 winner  target_runs       city  inning  \
# 124    335982  Kolkata Knight Riders        223.0  Bangalore       2
# 125    335982  Kolkata Knight Riders        223.0  Bangalore       2
# 126    335982  Kolkata Knight Riders        223.0  Bangalore       2
# 127    335982  Kolkata Knight Riders        223.0  Bangalore       2
# 128    335982  Kolkata Knight Riders        223.0  Bangalore       2
#
#                     batting_team           bowling_team  over  ball    batter  \
# 124  Royal Challengers Bangalore  Kolkata Knight Riders     0     1  R Dravid
# 125  Royal Challengers Bangalore  Kolkata Knight Riders     0     2  W Jaffer
# 126  Royal Challengers Bangalore  Kolkata Knight Riders     0     3  W Jaffer
# 127  Royal Challengers Bangalore  Kolkata Knight Riders     0     4  W Jaffer
# 128  Royal Challengers Bangalore  Kolkata Knight Riders     0     5  R Dravid
#
#      ... extra_runs total_runs  extras_type  is_wicket  player_dismissed  \
# 124  ...          0          1          NaN          0               NaN
# 125  ...          1          1        wides          0               NaN
# 126  ...          0          0          NaN          0               NaN
# 127  ...          0          1          NaN          0               NaN
# 128  ...          0          1          NaN          0               NaN
#
#     dismissal_kind  fielder current_score runs_left balls_left
# 124            NaN      NaN             1     222.0        119
# 125            NaN      NaN             2     221.0        118
# 126            NaN      NaN             2     221.0        117
# 127            NaN      NaN             3     220.0        116
# 128            NaN      NaN             4     219.0        115
#
# [5 rows x 23 columns]

# %%
# delivery_df['crr'].unique()

# %% [markdown]
# We use the cumsum on 'is_wicket' column to calculate the number of <b>wickets</b> left after every ball (10 - wickets)

# %%
wickets = delivery_df.groupby('match_id')['is_wicket'].transform('cumsum')
delivery_df['wickets_left'] = 10 - wickets
delivery_df.head()
# Out:
#      match_id                 winner  target_runs       city  inning  \
# 124    335982  Kolkata Knight Riders        223.0  Bangalore       2
# 125    335982  Kolkata Knight Riders        223.0  Bangalore       2
# 126    335982  Kolkata Knight Riders        223.0  Bangalore       2
# 127    335982  Kolkata Knight Riders        223.0  Bangalore       2
# 128    335982  Kolkata Knight Riders        223.0  Bangalore       2
#
#                     batting_team           bowling_team  over  ball    batter  \
# 124  Royal Challengers Bangalore  Kolkata Knight Riders     0     1  R Dravid
# 125  Royal Challengers Bangalore  Kolkata Knight Riders     0     2  W Jaffer
# 126  Royal Challengers Bangalore  Kolkata Knight Riders     0     3  W Jaffer
# 127  Royal Challengers Bangalore  Kolkata Knight Riders     0     4  W Jaffer
# 128  Royal Challengers Bangalore  Kolkata Knight Riders     0     5  R Dravid
#
#      ... total_runs extras_type  is_wicket  player_dismissed  dismissal_kind  \
# 124  ...          1         NaN          0               NaN             NaN
# 125  ...          1       wides          0               NaN             NaN
# 126  ...          0         NaN          0               NaN             NaN
# 127  ...          1         NaN          0               NaN             NaN
# 128  ...          1         NaN          0               NaN             NaN
#
#     fielder  current_score runs_left balls_left wickets_left
# 124     NaN              1     222.0        119           10
# 125     NaN              2     221.0        118           10
# 126     NaN              2     221.0        117           10
# 127     NaN              3     220.0        116           10
# 128     NaN              4     219.0        115           10
#
# [5 rows x 24 columns]

# %% [markdown]
# Now to calculate the <b>Current Run Rate</b> (crr), we divide the current score by total overs bowled

# %%
delivery_df['crr'] = delivery_df["current_score"] / (delivery_df['over'] + delivery_df['ball']/6)
delivery_df.head()
# Out:
#      match_id                 winner  target_runs       city  inning  \
# 124    335982  Kolkata Knight Riders        223.0  Bangalore       2
# 125    335982  Kolkata Knight Riders        223.0  Bangalore       2
# 126    335982  Kolkata Knight Riders        223.0  Bangalore       2
# 127    335982  Kolkata Knight Riders        223.0  Bangalore       2
# 128    335982  Kolkata Knight Riders        223.0  Bangalore       2
#
#                     batting_team           bowling_team  over  ball    batter  \
# 124  Royal Challengers Bangalore  Kolkata Knight Riders     0     1  R Dravid
# 125  Royal Challengers Bangalore  Kolkata Knight Riders     0     2  W Jaffer
# 126  Royal Challengers Bangalore  Kolkata Knight Riders     0     3  W Jaffer
# 127  Royal Challengers Bangalore  Kolkata Knight Riders     0     4  W Jaffer
# 128  Royal Challengers Bangalore  Kolkata Knight Riders     0     5  R Dravid
#
#      ... extras_type is_wicket  player_dismissed  dismissal_kind  fielder  \
# 124  ...         NaN         0               NaN             NaN      NaN
# 125  ...       wides         0               NaN             NaN      NaN
# 126  ...         NaN         0               NaN             NaN      NaN
# 127  ...         NaN         0               NaN             NaN      NaN
# 128  ...         NaN         0               NaN             NaN      NaN
#
#     current_score  runs_left balls_left wickets_left  crr
# 124             1      222.0        119           10  6.0
# 125             2      221.0        118           10  6.0
# 126             2      221.0        117           10  4.0
# 127             3      220.0        116           10  4.5
# 128             4      219.0        115           10  4.8
#
# [5 rows x 25 columns]

# %% [markdown]
# For <b>Required Run Rate</b> (rrr) we will divide runs_left by balls_left and multiply by 6

# %%
delivery_df['rrr'] = (delivery_df['runs_left']/delivery_df['balls_left']) * 6
delivery_df.head()
# Out:
#      match_id                 winner  target_runs       city  inning  \
# 124    335982  Kolkata Knight Riders        223.0  Bangalore       2
# 125    335982  Kolkata Knight Riders        223.0  Bangalore       2
# 126    335982  Kolkata Knight Riders        223.0  Bangalore       2
# 127    335982  Kolkata Knight Riders        223.0  Bangalore       2
# 128    335982  Kolkata Knight Riders        223.0  Bangalore       2
#
#                     batting_team           bowling_team  over  ball    batter  \
# 124  Royal Challengers Bangalore  Kolkata Knight Riders     0     1  R Dravid
# 125  Royal Challengers Bangalore  Kolkata Knight Riders     0     2  W Jaffer
# 126  Royal Challengers Bangalore  Kolkata Knight Riders     0     3  W Jaffer
# 127  Royal Challengers Bangalore  Kolkata Knight Riders     0     4  W Jaffer
# 128  Royal Challengers Bangalore  Kolkata Knight Riders     0     5  R Dravid
#
#      ... is_wicket player_dismissed  dismissal_kind  fielder  current_score  \
# 124  ...         0              NaN             NaN      NaN              1
# 125  ...         0              NaN             NaN      NaN              2
# 126  ...         0              NaN             NaN      NaN              2
# 127  ...         0              NaN             NaN      NaN              3
# 128  ...         0              NaN             NaN      NaN              4
#
#     runs_left  balls_left wickets_left  crr        rrr
# 124     222.0         119           10  6.0  11.193277
# 125     221.0         118           10  6.0  11.237288
# 126     221.0         117           10  4.0  11.333333
# 127     220.0         116           10  4.5  11.379310
# 128     219.0         115           10  4.8  11.426087
#
# [5 rows x 26 columns]

# %% [markdown]
# Now we need to make the <b>target variable</b>, 'result', which says whether the current batting team ultimately won the match. <br>
# We will apply a function which will return 1 if the batting team is the winner, else 0

# %%
def result(row):
    return 1 if row["batting_team"] == row["winner"] else 0

# %%
delivery_df['result'] = delivery_df.apply(result, axis=1)
delivery_df.head()
# Out:
#      match_id                 winner  target_runs       city  inning  \
# 124    335982  Kolkata Knight Riders        223.0  Bangalore       2
# 125    335982  Kolkata Knight Riders        223.0  Bangalore       2
# 126    335982  Kolkata Knight Riders        223.0  Bangalore       2
# 127    335982  Kolkata Knight Riders        223.0  Bangalore       2
# 128    335982  Kolkata Knight Riders        223.0  Bangalore       2
#
#                     batting_team           bowling_team  over  ball    batter  \
# 124  Royal Challengers Bangalore  Kolkata Knight Riders     0     1  R Dravid
# 125  Royal Challengers Bangalore  Kolkata Knight Riders     0     2  W Jaffer
# 126  Royal Challengers Bangalore  Kolkata Knight Riders     0     3  W Jaffer
# 127  Royal Challengers Bangalore  Kolkata Knight Riders     0     4  W Jaffer
# 128  Royal Challengers Bangalore  Kolkata Knight Riders     0     5  R Dravid
#
#      ... player_dismissed dismissal_kind  fielder  current_score  runs_left  \
# 124  ...              NaN            NaN      NaN              1      222.0
# 125  ...              NaN            NaN      NaN              2      221.0
# 126  ...              NaN            NaN      NaN              2      221.0
# 127  ...              NaN            NaN      NaN              3      220.0
# 128  ...              NaN            NaN      NaN              4      219.0
#
#     balls_left  wickets_left  crr        rrr result
# 124        119            10  6.0  11.193277      0
# 125        118            10  6.0  11.237288      0
# 126        117            10  4.0  11.333333      0
# 127        116            10  4.5  11.379310      0
# 128        115            10  4.8  11.426087      0
#
# [5 rows x 27 columns]

# %%
final_df = delivery_df[['batting_team', 'bowling_team', 'city', 'runs_left', 'balls_left', 'wickets_left', 'crr', 'rrr', 'result']]
final_df
# Out:
#                        batting_team           bowling_team       city  \
# 124     Royal Challengers Bangalore  Kolkata Knight Riders  Bangalore
# 125     Royal Challengers Bangalore  Kolkata Knight Riders  Bangalore
# 126     Royal Challengers Bangalore  Kolkata Knight Riders  Bangalore
# 127     Royal Challengers Bangalore  Kolkata Knight Riders  Bangalore
# 128     Royal Challengers Bangalore  Kolkata Knight Riders  Bangalore
# ...                             ...                    ...        ...
# 210963        Kolkata Knight Riders    Sunrisers Hyderabad    Chennai
# 210964        Kolkata Knight Riders    Sunrisers Hyderabad    Chennai
# 210965        Kolkata Knight Riders    Sunrisers Hyderabad    Chennai
# 210966        Kolkata Knight Riders    Sunrisers Hyderabad    Chennai
# 210967        Kolkata Knight Riders    Sunrisers Hyderabad    Chennai
#
#         runs_left  balls_left  wickets_left        crr        rrr  result
# 124         222.0         119            10   6.000000  11.193277       0
# 125         221.0         118            10   6.000000  11.237288       0
# 126         221.0         117            10   4.000000  11.333333       0
# 127         220.0         116            10   4.500000  11.379310       0
# 128         219.0         115            10   4.800000  11.426087       0
# ...           ...         ...           ...        ...        ...     ...
# 210963        4.0          61             8  11.186441   0.393443       1
# 210964        3.0          60             8  11.100000   0.300000       1
# 210965        2.0          59             8  11.016393   0.203390       1
# 210966        1.0          58             8  10.935484   0.103448       1
# 210967        0.0          57             8  10.857143   0.000000       1
#
# [102034 rows x 9 columns]

# %%
final_df = final_df.sample(final_df.shape[0])

# %%
final_df.isnull().sum()
# Out:
# batting_team       0
# bowling_team       0
# city            6012
# runs_left          0
# balls_left         0
# wickets_left       0
# crr                0
# rrr               13
# result             0
# dtype: int64

# %%
# final_df[final_df['balls_left'] == 0]['rrr'] = 0
final_df.loc[final_df['balls_left'] == 0, 'rrr'] = 0

final_df
# Out:
#                        batting_team                 bowling_team       city  \
# 27175         Kolkata Knight Riders  Royal Challengers Bangalore    Kolkata
# 38332                Delhi Capitals          Chennai Super Kings    Chennai
# 119357               Delhi Capitals          Sunrisers Hyderabad      Delhi
# 123051  Royal Challengers Bangalore                 Punjab Kings  Bengaluru
# 57434           Chennai Super Kings                 Punjab Kings    Chennai
# ...                             ...                          ...        ...
# 71244                Mumbai Indians        Kolkata Knight Riders    Kolkata
# 139629                 Punjab Kings          Chennai Super Kings    Chennai
# 131914          Chennai Super Kings          Sunrisers Hyderabad       Pune
# 205134               Delhi Capitals          Sunrisers Hyderabad      Delhi
# 27421           Chennai Super Kings          Sunrisers Hyderabad    Chennai
#
#         runs_left  balls_left  wickets_left        crr        rrr  result
# 27175       117.0         102            10   6.333333   6.882353       1
# 38332        63.0          66             6   5.555556   5.727273       0
# 119357       29.0          20             6   9.420000   8.700000       0
# 123051      155.0         118             9   3.000000   7.881356       1
# 57434       101.0          79             9   8.195122   7.670886       0
# ...           ...         ...           ...        ...        ...     ...
# 71244        44.0          30             7   7.733333   8.800000       1
# 139629       53.0          27             8   6.967742  11.777778       0
# 131914       23.0          23             8   9.711340   6.000000       1
# 205134      181.0          85             8  14.742857  12.776471       0
# 27421       179.0         108            10   6.000000   9.944444       0
#
# [102034 rows x 9 columns]

# %%
final_df.shape
# Out:
# (102034, 9)

# %%
final_df.dropna(inplace=True)

# %%
final_df.shape
# Out:
# (96022, 9)

# %%
X = final_df.iloc[:, :-1]
y = final_df.iloc[:, -1]
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=1)

# %%
from sklearn.compose import ColumnTransformer
from sklearn.preprocessing import OneHotEncoder

trf = ColumnTransformer([
    ('trf', OneHotEncoder(sparse_output=False, drop='first'), ['batting_team', 'bowling_team', 'city'])
], remainder='passthrough', force_int_remainder_cols=False)

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.pipeline import Pipeline

# %%
pipe = Pipeline(steps=[
    ('step1', trf),
    ('step2', LogisticRegression(solver='liblinear'))
])

# %%
pipe.fit(X_train, y_train)
# Out:
# Pipeline(steps=[('step1',
#                  ColumnTransformer(force_int_remainder_cols=False,
#                                    remainder='passthrough',
#                                    transformers=[('trf',
#                                                   OneHotEncoder(drop='first',
#                                                                 sparse_output=False),
#                                                   ['batting_team',
#                                                    'bowling_team', 'city'])])),
#                 ('step2', LogisticRegression(solver='liblinear'))])

# %%
y_pred = pipe.predict(X_test)

# %%
from sklearn.metrics import accuracy_score
accuracy_score(y_test, y_pred)
# Out:
# 0.8159333506899245

# %%
pipe.predict_proba(X_test)
# Out:
# array([[0.07390382, 0.92609618],
#        [0.55945457, 0.44054543],
#        [0.99583236, 0.00416764],
#        ...,
#        [0.75591653, 0.24408347],
#        [0.75644457, 0.24355543],
#        [0.17622276, 0.82377724]])

# %%
import pickle
pickle.dump(pipe, open('pipe.pkl', 'wb'))

# %%
final_df[final_df['balls_left'] == 0]
# Out:
#                        batting_team           bowling_team       city  \
# 164366  Royal Challengers Bangalore         Mumbai Indians    Chennai
# 198141               Delhi Capitals           Punjab Kings      Delhi
# 10063                Mumbai Indians           Punjab Kings     Mumbai
# 11789              Rajasthan Royals         Mumbai Indians     Jaipur
# 54369         Kolkata Knight Riders           Punjab Kings    Kolkata
# ...                             ...                    ...        ...
# 7291                   Punjab Kings    Chennai Super Kings    Chennai
# 192776          Sunrisers Hyderabad         Mumbai Indians  Hyderabad
# 204721             Rajasthan Royals  Kolkata Knight Riders    Kolkata
# 59197           Sunrisers Hyderabad    Chennai Super Kings    Chennai
# 167056             Rajasthan Royals    Chennai Super Kings     Mumbai
#
#         runs_left  balls_left  wickets_left    crr  rrr  result
# 164366        0.0           0             2   8.00  0.0       1
# 198141       32.0           0             2   6.80  0.0       0
# 10063         2.0           0             1   9.40  0.0       0
# 11789         2.0           0             5   7.20  0.0       1
# 54369         3.0           0             3   6.60  0.0       0
# ...           ...         ...           ...    ...  ...     ...
# 7291         19.0           0             1   8.15  0.0       0
# 192776       15.0           0             0   8.90  0.0       0
# 204721        0.0           0             2  11.20  0.0       1
# 59197        11.0           0             5   7.50  0.0       0
# 167056       46.0           0             1   7.15  0.0       0
#
# [325 rows x 9 columns]

# %% [markdown]
# Debugging...ignore

# %%
final_df[final_df['balls_left'] == 0]
# Out:
#                        batting_team           bowling_team       city  \
# 164366  Royal Challengers Bangalore         Mumbai Indians    Chennai
# 198141               Delhi Capitals           Punjab Kings      Delhi
# 10063                Mumbai Indians           Punjab Kings     Mumbai
# 11789              Rajasthan Royals         Mumbai Indians     Jaipur
# 54369         Kolkata Knight Riders           Punjab Kings    Kolkata
# ...                             ...                    ...        ...
# 7291                   Punjab Kings    Chennai Super Kings    Chennai
# 192776          Sunrisers Hyderabad         Mumbai Indians  Hyderabad
# 204721             Rajasthan Royals  Kolkata Knight Riders    Kolkata
# 59197           Sunrisers Hyderabad    Chennai Super Kings    Chennai
# 167056             Rajasthan Royals    Chennai Super Kings     Mumbai
#
#         runs_left  balls_left  wickets_left    crr  rrr  result
# 164366        0.0           0             2   8.00  0.0       1
# 198141       32.0           0             2   6.80  0.0       0
# 10063         2.0           0             1   9.40  0.0       0
# 11789         2.0           0             5   7.20  0.0       1
# 54369         3.0           0             3   6.60  0.0       0
# ...           ...         ...           ...    ...  ...     ...
# 7291         19.0           0             1   8.15  0.0       0
# 192776       15.0           0             0   8.90  0.0       0
# 204721        0.0           0             2  11.20  0.0       1
# 59197        11.0           0             5   7.50  0.0       0
# 167056       46.0           0             1   7.15  0.0       0
#
# [325 rows x 9 columns]

# %%
X_train.isnull().sum()
# Out:
# batting_team    0
# bowling_team    0
# city            0
# runs_left       0
# balls_left      0
# wickets_left    0
# crr             0
# rrr             0
# dtype: int64

# %%
X.isnull().sum()
# Out:
# batting_team    0
# bowling_team    0
# city            0
# runs_left       0
# balls_left      0
# wickets_left    0
# crr             0
# rrr             0
# dtype: int64

# %%
final_df.isnull().sum()
# Out:
# batting_team    0
# bowling_team    0
# city            0
# runs_left       0
# balls_left      0
# wickets_left    0
# crr             0
# rrr             0
# result          0
# dtype: int64

# %%
final_df['city'].unique()
# Out:
# array(['Kolkata', 'Chennai', 'Delhi', 'Bengaluru', 'Mumbai',
#        'Visakhapatnam', 'Bangalore', 'Cape Town', 'Hyderabad', 'Ranchi',
#        'Chandigarh', 'Jaipur', 'Pune', 'Centurion', 'Raipur',
#        'Johannesburg', 'Port Elizabeth', 'Sharjah', 'Abu Dhabi',
#        'Navi Mumbai', 'Ahmedabad', 'Indore', 'Dubai', 'East London',
#        'Mohali', 'Dharamsala', 'Cuttack', 'Guwahati', 'Durban',
#        'Kimberley', 'Nagpur', 'Bloemfontein'], dtype=object)

# %%
X['city'].unique()
# Out:
# array(['Kolkata', 'Chennai', 'Delhi', 'Bengaluru', 'Mumbai',
#        'Visakhapatnam', 'Bangalore', 'Cape Town', 'Hyderabad', 'Ranchi',
#        'Chandigarh', 'Jaipur', 'Pune', 'Centurion', 'Raipur',
#        'Johannesburg', 'Port Elizabeth', 'Sharjah', 'Abu Dhabi',
#        'Navi Mumbai', 'Ahmedabad', 'Indore', 'Dubai', 'East London',
#        'Mohali', 'Dharamsala', 'Cuttack', 'Guwahati', 'Durban',
#        'Kimberley', 'Nagpur', 'Bloemfontein'], dtype=object)

# %%
X[X['city'].isnull()]
# Out:
# Empty DataFrame
# Columns: [batting_team, bowling_team, city, runs_left, balls_left, wickets_left, crr, rrr]
# Index: []

# %%
X[X['balls_left'] == 0]
# Out:
#                        batting_team           bowling_team       city  \
# 164366  Royal Challengers Bangalore         Mumbai Indians    Chennai
# 198141               Delhi Capitals           Punjab Kings      Delhi
# 10063                Mumbai Indians           Punjab Kings     Mumbai
# 11789              Rajasthan Royals         Mumbai Indians     Jaipur
# 54369         Kolkata Knight Riders           Punjab Kings    Kolkata
# ...                             ...                    ...        ...
# 7291                   Punjab Kings    Chennai Super Kings    Chennai
# 192776          Sunrisers Hyderabad         Mumbai Indians  Hyderabad
# 204721             Rajasthan Royals  Kolkata Knight Riders    Kolkata
# 59197           Sunrisers Hyderabad    Chennai Super Kings    Chennai
# 167056             Rajasthan Royals    Chennai Super Kings     Mumbai
#
#         runs_left  balls_left  wickets_left    crr  rrr
# 164366        0.0           0             2   8.00  0.0
# 198141       32.0           0             2   6.80  0.0
# 10063         2.0           0             1   9.40  0.0
# 11789         2.0           0             5   7.20  0.0
# 54369         3.0           0             3   6.60  0.0
# ...           ...         ...           ...    ...  ...
# 7291         19.0           0             1   8.15  0.0
# 192776       15.0           0             0   8.90  0.0
# 204721        0.0           0             2  11.20  0.0
# 59197        11.0           0             5   7.50  0.0
# 167056       46.0           0             1   7.15  0.0
#
# [325 rows x 8 columns]

# %%
final_df['batting_team'].unique()
# Out:
# array(['Kolkata Knight Riders', 'Delhi Capitals',
#        'Royal Challengers Bangalore', 'Chennai Super Kings',
#        'Mumbai Indians', 'Rajasthan Royals', 'Sunrisers Hyderabad',
#        'Punjab Kings'], dtype=object)

# %%
matches['team1'].unique()
# Out:
# array(['Royal Challengers Bangalore', 'Punjab Kings', 'Delhi Capitals',
#        'Mumbai Indians', 'Kolkata Knight Riders', 'Rajasthan Royals',
#        'Sunrisers Hyderabad', 'Chennai Super Kings'], dtype=object)

# %%
delivery_df['batting_team'].unique()
# Out:
# array(['Royal Challengers Bangalore', 'Punjab Kings', 'Delhi Capitals',
#        'Kolkata Knight Riders', 'Rajasthan Royals', 'Mumbai Indians',
#        'Chennai Super Kings', 'Sunrisers Hyderabad'], dtype=object)
